# %%
# !git clone https://github.com/ultralytics/ultralytics.git  # clone repo
# %cd ultralytics
# Out:
# c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --[no-]verbose    be more verbose
#     -q, --[no-]quiet      be more quiet
#     --[no-]progress       force progress reporting
#     --[no-]reject-shallow don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --checkout            opposite of --no-checkout
#     --[no-]bare           create a bare repository
#     --[no-]mirror         create a mirror repository (implies --bare)
#     -l, --[no-]local      to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     --hardlinks           opposite of --no-hardlinks
#     -s, --[no-]shared     setup as shared repository
#     --[no-]recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
# ...

# %%
# %cd ultralytics
# Out:
# [WinError 2] The system cannot find the file specified: 'ultralytics'
# c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 13.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/783.6 kB ? eta -:--:--
#    ---------------------------------------- 783.6/783.6 kB 20.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---- ----------------------------------- 5.0/41.3 MB 24.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.5/41.3 MB 25.5 MB/s eta 0:00:02
#    -------------- ------------------------- 15.2/41.3 MB 24.5 MB/s eta 0:00:02
#    -------------------- ------------------- 21.2/41.3 MB 25.2 MB/s eta 0:00:01
#    ------------------------- -------------- 26.7/41.3 MB 25.1 MB/s eta 0:00:01
#    ------------------------------- -------- 33.0/41.3 MB 26.4 MB/s eta 0:00:01
#    ------------------------------------- -- 39.1/41.3 MB 26.5 MB/s eta 0:00:01
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
import sys
import os

cur = os.path.join(os.getcwd(), '..')
print(cur)
proj_path = os.path.abspath(
    os.path.join(os.getcwd(), '..')
)
coralpath = os.path.join(proj_path)
print(coralpath)

sys.path.insert(0, coralpath)
print(
    sys.path
)# # Assume your notebook is in <project_root>/coralscapes/, and coralscapesScripts is in <project_root>/
# project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
# if project_root not in sys.path:
#     sys.path.insert(0, project_root)
# Out:
# c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics\..
# c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics
# ['c:\\Users\\muham\\OneDrive - TU Eindhoven\\Extended-evaluation-snowpole-lidar-dataset\\ultralytics', 'c:\\Users\\muham\\OneDrive - TU Eindhoven\\Extended-evaluation-snowpole-lidar-dataset\\ultralytics\\coralscapesScripts', 'c:\\Users\\muham\\anaconda3\\python313.zip', 'c:\\Users\\muham\\anaconda3\\DLLs', 'c:\\Users\\muham\\anaconda3\\Lib', 'c:\\Users\\muham\\anaconda3', '', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
print(
    sys.path
)
# Out:
# ['c:\\Users\\muham\\OneDrive - TU Eindhoven\\Extended-evaluation-snowpole-lidar-dataset\\ultralytics', 'c:\\Users\\muham\\OneDrive - TU Eindhoven\\Extended-evaluation-snowpole-lidar-dataset\\ultralytics\\coralscapesScripts', 'c:\\Users\\muham\\anaconda3\\python313.zip', 'c:\\Users\\muham\\anaconda3\\DLLs', 'c:\\Users\\muham\\anaconda3\\Lib', 'c:\\Users\\muham\\anaconda3', '', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\muham\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
import os
from pathlib import Path

print("cwd:", Path.cwd())  # see where the process is running
data_dir = Path.cwd() / "../../range-normalized"
for root, dirs, files in os.walk(data_dir):
    print(f"Root: {root}")
    print(f"Dirs: {dirs}")
    # print(f"Files: {files}")
# Out:
# cwd: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics
# here
# Root: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics\..\..\range-normalized
# Dirs: ['images', 'labels', 'test', 'train', 'valid']
# Root: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics\..\..\range-normalized\images
# Dirs: ['test', 'train', 'valid']
# Root: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics\..\..\range-normalized\images\test
# Dirs: []
# Root: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics\..\..\range-normalized\images\train
# Dirs: []
# Root: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics\..\..\range-normalized\images\valid
# Dirs: []
# ...

# %%
print("cwd:", Path.cwd())  # see where the process is running
# Out:
# cwd: c:\Users\muham\OneDrive - TU Eindhoven\Extended-evaluation-snowpole-lidar-dataset\ultralytics\ultralytics

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# !yolo train model=yolov9t.pt epochs=150 imgsz=1024 device=cpu batch=8 name=range_norm data='../../range-normalized' project='../../range-normalized'
# !yolo train model=yolov9t.pt epochs=150 imgsz=1024 device=cpu batch=8 name=range_norm data="C:\\Users\\muham\\OneDrive - TU Eindhoven\\Extended-evaluation-snowpole-lidar-dataset\\range-normalized\\data.yaml" project="C:\\Users\\muham\\OneDrive - TU Eindhoven\\Extended-evaluation-snowpole-lidar-dataset\\range-normalized"
# Out:
# ^C

# %%
import os
import zipfile
import shutil
import base64
from IPython.display import HTML

exp_path = '/kaggle/working/train_'  # Adjust this path if needed

if os.path.exists(exp_path):
    zip_filename = 'trained_yolov5_model.zip'
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(exp_path):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, exp_path)
                zipf.write(file_path, arcname)
    print("You can now download this ZIP file from Kaggle!")
    
    # List contents of the ZIP
    with zipfile.ZipFile(zip_filename, 'r') as zipf:
        print(f"\nZIP contents:")
        for file in zipf.namelist():
            print(f"  - {file}")
    # Read the ZIP file and encode it
    with open(zip_filename, 'rb') as f:
        zip_data = f.read()
    
    # Create a download link
    b64 = base64.b64encode(zip_data).decode()
    download_link = f'''
    <div style="text-align: center; padding: 20px; border: 3px solid #4CAF50; border-radius: 15px; margin: 20px; background-color: #f0f8f0;">
        <h2 style="color: #4CAF50; margin-bottom: 20px;">�� YOUR TRAINED MODEL IS READY!</h2>
        <p style="font-size: 18px; margin-bottom: 20px;">Click the button below to download your trained YOLOv5 model:</p>
        <a href="data:application/zip;base64,{b64}" download="{zip_filename}" 
           style="background-color: #4CAF50; color: white; padding: 20px 40px; text-decoration: none; 
                  font-size: 20px; border-radius: 10px; display: inline-block; margin: 10px; font-weight: bold;">
           📥 DOWNLOAD {zip_filename}
        </a>
        <p style="color: #666; margin-top: 15px;">File size: {os.path.getsize(zip_filename) / (1024*1024):.2f} MB</p>
        <p style="color: #888; font-size: 14px;">This will download your complete trained model with weights, results, and visualizations</p>
    </div>
    '''
    
    # Display the download link
    display(HTML(download_link))
  
    js_code = f'''
    <script>
    console.log("🚀 Auto-download script started");
    setTimeout(function() {{
        var link = document.createElement('a');
        link.href = '{zip_filename}';
        link.download = '{zip_filename}';
        link.style.display = 'none';
        document.body.appendChild(link);
        link.click();
        document.body.removeChild(link);
        console.log("✅ Download link clicked automatically");
    }}, 2000);
    </script>
    '''
    
    display(HTML(js_code))
